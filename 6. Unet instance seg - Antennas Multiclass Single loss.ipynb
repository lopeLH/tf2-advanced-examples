# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %%
tf.test.is_gpu_available()
# Out:
# True

# %%
from datasets.utils import generate_train_and_test_data
from datasets.segmentation.circle_segmentation import circle_segmentation_sample

# %%
from sklearn.neighbors import NearestNeighbors

def embeddings_to_instances(embeddings_map, segmentation,
                            embedding_distance_threshold = 0.5, segmentation_threshold = 0.5,
                            center_change_tol = 0.001, min_samples_per_instance = 20):
    
    embedding_dim = embeddings_map.shape[-1]
    relevant_embedding_selection_mask = (segmentation > segmentation_threshold).ravel()
    embeddings = embeddings_map.reshape((-1, embedding_dim))[relevant_embedding_selection_mask]
    
    nn = NearestNeighbors().fit(embeddings)
    
    labels = np.full(len(embeddings), -1, dtype=np.int32)
    
    instance_id = 0
    while np.any(labels == -1):
        
        unclustered_idxs = np.where(labels == -1)[0]
        seed_idx = unclustered_idxs[np.random.randint(len(unclustered_idxs))]
        
        center = embeddings[seed_idx]
        
        center_change = np.inf
        while center_change > center_change_tol:
            in_radius_idxs = nn.radius_neighbors(
                [center], return_distance=False, radius=embedding_distance_threshold)[0]
            new_center = np.mean(embeddings[in_radius_idxs], axis=0) if len(in_radius_idxs) > 0 else center
            
            center_change = np.linalg.norm(center - new_center)
            center = new_center

        labels[in_radius_idxs] = instance_id
        labels[seed_idx] = instance_id
        instance_id += 1
        
        points_left = np.sum(labels==-1)
        
    
    values, counts = np.unique(labels, return_counts=True)
    for (label, count) in zip(values, counts):
        if count < min_samples_per_instance:            
            labels[labels == label] = -1
        
    new_label = 0
    for label in np.unique(labels):
        if label != -1:
            labels[labels == label] = new_label
            new_label += 1
        
    full_image_labels = np.full(np.prod(embeddings_map.shape[:2]), -1, dtype=np.int32)
    full_image_labels[relevant_embedding_selection_mask] = labels
    
    return full_image_labels.reshape(embeddings_map.shape[:2])

# %%
import cv2
import numpy as np
import math

class RRect_center:
    def __init__(self, p0, s, ang):
        (self.W, self.H) = s # rectangle width and height
        self.d = math.sqrt(self.W**2 + self.H**2)/2.0 # distance from center to vertices    
        self.c = (int(p0[0]+self.W/2.0),int(p0[1]+self.H/2.0)) # center point coordinates
        self.ang = ang # rotation angle
        self.alpha = math.radians(self.ang) # rotation angle in radians
        self.beta = math.atan2(self.H, self.W) # angle between d and horizontal axis
        # Center Rotated vertices in image frame
        self.P0 = (int(self.c[0] - self.d * math.cos(self.beta - self.alpha)), int(self.c[1] - self.d * math.sin(self.beta-self.alpha))) 
        self.P1 = (int(self.c[0] - self.d * math.cos(self.beta + self.alpha)), int(self.c[1] + self.d * math.sin(self.beta+self.alpha))) 
        self.P2 = (int(self.c[0] + self.d * math.cos(self.beta - self.alpha)), int(self.c[1] + self.d * math.sin(self.beta-self.alpha))) 
        self.P3 = (int(self.c[0] + self.d * math.cos(self.beta + self.alpha)), int(self.c[1] - self.d * math.sin(self.beta+self.alpha))) 

        self.verts = [self.P0,self.P1,self.P2,self.P3]

    def draw(self, image, color_border=255, color_fill=0):
        rect = cv2.minAreaRect(np.asarray(self.verts))
        box = cv2.boxPoints(rect)
        box = np.int0(box)
        cv2.drawContours(image,[box],0,color_fill,-1)
        cv2.drawContours(image,[box],0,color_border,2)
        
    def fill_value(self, image, value):
        rect = cv2.minAreaRect(np.asarray(self.verts))
        box = cv2.boxPoints(rect)
        box = np.int0(box)
        cv2.drawContours(image,[box],0,value,-1)

from datasets.segmentation.circle_segmentation import random_rgb_color
        
    
background = cv2.imread("/home/dlopez/Downloads/files1708/data_inspID1708_projID767414/figures/ADJI_0001 (457).JPG")[...,::-1]    
background = cv2.resize(background, None, fx=0.5, fy=0.5)
def sticks_instance_segmentation_sample(width, height, max_sticks=5, background=background):

    i = np.random.randint(0, background.shape[0]-height)
    j = np.random.randint(0, background.shape[1]-width)

    img = background[i:i+height, j:j+width].copy()
    mask = np.zeros((height, width, 1)).astype(np.uint8)
    mask2 = np.zeros((height, width, 1)).astype(np.uint8)
    n_sticks = np.random.randint(2, max_sticks)
   
    for i in range(1, n_sticks+1):
        
        top_left = (np.random.randint(20, width-20), np.random.randint(20, height-20)) 
        angles = np.random.randint(-30, 30)
        
        rect = RRect_center(top_left, (10, 50), angles)
        while not all([(0 < x[0] < width) and (0 < x[1] < height) for x in rect.verts]):
            top_left = (np.random.randint(20, width-20), np.random.randint(20, height-20)) 
            rect = RRect_center(top_left, (10, 50), angles)
        
        rect.draw(img, color_fill=(190,190,190), color_border=(80,80,80))
       
        rect.fill_value(mask, i)

        
    for i in range(1, n_sticks):
        
        center = (np.random.randint(20, width-20), np.random.randint(20, height-20)) 
                
        cv2.circle(img, center, 12, (190, 190, 190), -1)
        cv2.circle(img, center, 12, (80, 80, 80), 2)
       
        cv2.circle(mask, center, 12, 0, -1)
        cv2.circle(mask2, center, 12, i+n_sticks, -1)
        
        
    return img, np.concatenate([mask, mask2], axis=-1)

# %%
(X_train, Y_train), (X_test, Y_test) = \
    generate_train_and_test_data(sticks_instance_segmentation_sample, width=128, height=128, n_samples_train=30000)

# %%
for ch in range(2):
    plt.imshow(Y_train[0][...,ch])
    plt.show()
    plt.imshow(X_train[0])
    plt.show()
    
plt.imshow(Y_train[0][...,0] + (np.max(Y_train[0][...,0]) + Y_train[0][...,1]))

# %%
Y_train_i = np.where(Y_train[...,0] > 0.5, Y_train[...,0], 0) \
            + np.where(Y_train[...,1] > 0.5, Y_train[...,1], 0)

# %%
plt.imshow(Y_train_i[3])

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
input = keras.layers.Input((128, 128, 3))

conv1 = keras.layers.Conv2D(32, (3,3), activation="relu", padding="same")(input) 
maxp1 = keras.layers.MaxPool2D((2,2))(conv1)                                    

conv2 = keras.layers.Conv2D(64, (3,3), activation="relu", padding="same")(maxp1) 
maxp2 = keras.layers.MaxPool2D((2,2))(conv2)                                     
 
conv3 = keras.layers.Conv2D(128, (3,3), activation="relu", padding="same")(maxp2)
maxp3 = keras.layers.MaxPool2D((2,2))(conv3)  

conv4 = keras.layers.Conv2D(256, (3,3), activation="relu", padding="same")(maxp3)
maxp4 = keras.layers.MaxPool2D((2,2))(conv4)


tconv5 = keras.layers.Conv2DTranspose(256, (3,3), strides=(2,2),                       
                                      padding="same", activation="relu")(maxp4) 
con5 = keras.layers.concatenate([tconv5, conv4], axis=3)

tconv6 = keras.layers.Conv2DTranspose(128, (3,3), strides=(2,2),                       
                                      padding="same", activation="relu")(con5)  
con6 = keras.layers.concatenate([tconv6, conv3], axis=3)  

tconv7 = keras.layers.Conv2DTranspose(64, (3,3), strides=(2,2),                       
                                      padding="same", activation="relu")(con6)  
con7 = keras.layers.concatenate([tconv7, conv2], axis=3)                      

tconv8 = keras.layers.Conv2DTranspose(64, (3,3), strides=(2,2),                       
                                      padding="same", activation="relu")(con7)  
con8 = keras.layers.concatenate([tconv8, conv1], axis=3)                      

embd = keras.layers.Conv2D(3, (1,1), padding="same", activation="linear", use_bias=False, name="embedding")(con8)
segm = keras.layers.Conv2D(2, (1,1), padding="same", activation="sigmoid", name="segmentation")(con8)

model = keras.models.Model(input, [segm, embd])
# model = keras.models.Model(input, embd)

# %%
keras.utils.plot_model(model, show_layer_names=False, show_shapes=True)

# %%
def discriminative_loss_single(
        prediction,
        correct_label,
        feature_dim,
        label_shape,
        delta_v,
        delta_d,
        param_var,
        param_dist,
        param_reg):
    """
    discriminative loss
    :param prediction: inference of network
    :param correct_label: instance label
    :param feature_dim: feature dimension of prediction
    :param label_shape: shape of label
    :param delta_v: cut off variance distance
    :param delta_d: cut off cluster distance
    :param param_var: weight for intra cluster variance
    :param param_dist: weight for inter cluster distances
    :param param_reg: weight regularization
    """
    correct_label = tf.reshape(
        correct_label, [label_shape[1] * label_shape[0]]
    )
    reshaped_pred = tf.reshape(
        prediction, [label_shape[1] * label_shape[0], feature_dim]
    )
    
    #foreground_mask = tf.not_equal(correct_label, 0)
    #correct_label = tf.boolean_mask(correct_label, foreground_mask)
    #reshaped_pred = tf.boolean_mask(reshaped_pred, foreground_mask)

    # calculate instance nums
    unique_labels, unique_id, counts = tf.unique_with_counts(correct_label)
    counts = tf.cast(counts, tf.float32)
    num_instances = tf.size(unique_labels)

    # calculate instance pixel embedding mean vec
    segmented_sum = tf.unsorted_segment_sum(
        reshaped_pred, unique_id, num_instances)
    mu = tf.div(segmented_sum, tf.reshape(counts, (-1, 1)))
    mu_expand = tf.gather(mu, unique_id)

    distance = tf.norm(tf.subtract(mu_expand, reshaped_pred), axis=1, ord=1)
    distance = tf.subtract(distance, delta_v)
    distance = tf.clip_by_value(distance, 0., distance)
    distance = tf.square(distance)

    l_var = tf.unsorted_segment_sum(distance, unique_id, num_instances)
    l_var = tf.div(l_var, counts)
    l_var = tf.reduce_sum(l_var)
    l_var = tf.divide(l_var, tf.cast(num_instances, tf.float32))

    mu_interleaved_rep = tf.tile(mu, [num_instances, 1])
    mu_band_rep = tf.tile(mu, [1, num_instances])
    mu_band_rep = tf.reshape(
        mu_band_rep,
        (num_instances *
         num_instances,
         feature_dim))

    mu_diff = tf.subtract(mu_band_rep, mu_interleaved_rep)

    intermediate_tensor = tf.reduce_sum(tf.abs(mu_diff), axis=1)
    zero_vector = tf.zeros(1, dtype=tf.float32)
    bool_mask = tf.not_equal(intermediate_tensor, zero_vector)
    mu_diff_bool = tf.boolean_mask(mu_diff, bool_mask)

    mu_norm = tf.norm(mu_diff_bool, axis=1, ord=1)
    mu_norm = tf.subtract(2. * delta_d, mu_norm)
    mu_norm = tf.clip_by_value(mu_norm, 0., mu_norm)
    mu_norm = tf.square(mu_norm)

    l_dist = tf.reduce_mean(mu_norm)

    l_reg = tf.reduce_mean(tf.norm(mu, axis=1, ord=1))

    param_scale = 1.
    l_var = param_var * l_var
    l_dist = param_dist * l_dist
    l_dist = tf.cond(num_instances > 1 , lambda: l_dist, lambda: 0.)
    l_reg = param_reg * l_reg

    loss = param_scale * (l_var + l_dist + l_reg)
    
    #loss_not_nan = tf.dtypes.cast(tf.math.logical_not(tf.math.is_nan(loss)), dtype=tf.float32)
    #loss = tf.math.multiply_no_nan(loss, loss_not_nan)
    
    loss = tf.cond(num_instances > 0 , lambda: loss, lambda: 0.)

    return loss, l_var, l_dist, l_reg


def discriminative_loss(correct_label, prediction, feature_dim=3, image_shape=(128,128), 
                delta_v=0.5, delta_d=1.5, param_var=1, param_dist=1, param_reg=0.001):
    ''' Iterate over a batch of prediction/label and cumulate loss
    :return: discriminative loss and its three components
    '''
    def cond(label, batch, out_loss, out_var, out_dist, out_reg, i):
        return tf.less(i, tf.shape(batch)[0])

    def body(label, batch, out_loss, out_var, out_dist, out_reg, i):
        disc_loss, l_var, l_dist, l_reg = discriminative_loss_single(prediction[i], correct_label[i], feature_dim, image_shape, 
                        delta_v, delta_d, param_var, param_dist, param_reg)

        out_loss = out_loss.write(i, disc_loss)
        out_var = out_var.write(i, l_var)
        out_dist = out_dist.write(i, l_dist)
        out_reg = out_reg.write(i, l_reg)

        return label, batch, out_loss, out_var, out_dist, out_reg, i + 1

    # TensorArray is a data structure that support dynamic writing
    output_ta_loss = tf.TensorArray(dtype=tf.float32,
                   size=0,
                   dynamic_size=True)
    output_ta_var = tf.TensorArray(dtype=tf.float32,
                   size=0,
                   dynamic_size=True)
    output_ta_dist = tf.TensorArray(dtype=tf.float32,
                   size=0,
                   dynamic_size=True)
    output_ta_reg = tf.TensorArray(dtype=tf.float32,
                   size=0,
                   dynamic_size=True)

    _, _, out_loss_op, _, _, _, _  = tf.while_loop(cond, body, [correct_label, 
                                                        prediction, 
                                                        output_ta_loss, 
                                                        output_ta_var, 
                                                        output_ta_dist, 
                                                        output_ta_reg, 
                                                        0])
    out_loss_op = out_loss_op.stack()
    disc_loss = tf.reduce_mean(out_loss_op)

    return disc_loss

# %%
import keras.backend as K
from keras.losses import binary_crossentropy

losses = [binary_crossentropy, discriminative_loss]
losses_weights = [0.5, 0.5]

model.compile("adam", loss=losses)
model.fit(X_train, [Y_train > 0, Y_train_i], epochs=100, batch_size=32)
# Out:
# /home/dlopez/analytics-antenna-detection/artifacts/venv/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 30000 samples
# Epoch 1/100
# 30000/30000 [==============================] - 345s 11ms/sample - loss: 1.1462 - segmentation_loss: 0.1099 - embedding_loss: 1.0359
# Epoch 2/100
# 30000/30000 [==============================] - 378s 13ms/sample - loss: 0.3853 - segmentation_loss: 0.0203 - embedding_loss: 0.3650
# Epoch 3/100
# 30000/30000 [==============================] - 366s 12ms/sample - loss: 0.3020 - segmentation_loss: 0.0132 - embedding_loss: 0.2889
# Epoch 4/100
# 30000/30000 [==============================] - 339s 11ms/sample - loss: 0.2526 - segmentation_loss: 0.0102 - embedding_loss: 0.2424
# Epoch 5/100
# 30000/30000 [==============================] - 321s 11ms/sample - loss: 0.2187 - segmentation_loss: 0.0084 - embedding_loss: 0.2102
# Epoch 6/100
# 30000/30000 [==============================] - 310s 10ms/sample - loss: 0.1948 - segmentation_loss: 0.0073 - embedding_loss: 0.1875
# Epoch 7/100
# 30000/30000 [==============================] - 313s 10ms/sample - loss: 0.1760 - segmentation_loss: 0.0065 - embedding_loss: 0.1695
# Epoch 8/100
# 30000/30000 [==============================] - 310s 10ms/sample - loss: 0.1601 - segmentation_loss: 0.0058 - embedding_loss: 0.1543
# Epoch 9/100
# 30000/30000 [==============================] - 309s 10ms/sample - loss: 0.1471 - segmentation_loss: 0.0053 - embedding_loss: 0.1418
# Epoch 10/100
# 30000/30000 [==============================] - 307s 10ms/sample - loss: 0.1348 - segmentation_loss: 0.0048 - embedding_loss: 0.1300
# Epoch 11/100
# 30000/30000 [==============================] - 304s 10ms/sample - loss: 0.1253 - segmentation_loss: 0.0045 - embedding_loss: 0.1208
# Epoch 12/100
# 30000/30000 [==============================] - 302s 10ms/sample - loss: 0.1157 - segmentation_loss: 0.0041 - embedding_loss: 0.1116
# Epoch 13/100
# 30000/30000 [==============================] - 301s 10ms/sample - loss: 0.1080 - segmentation_loss: 0.0038 - embedding_loss: 0.1042
# Epoch 14/100
# 30000/30000 [==============================] - 300s 10ms/sample - loss: 0.1013 - segmentation_loss: 0.0036 - embedding_loss: 0.0978
# Epoch 15/100
# 30000/30000 [==============================] - 309s 10ms/sample - loss: 0.0955 - segmentation_loss: 0.0034 - embedding_loss: 0.0921
# Epoch 16/100
# 30000/30000 [==============================] - 305s 10ms/sample - loss: 0.0898 - segmentation_loss: 0.0032 - embedding_loss: 0.0866
# Epoch 17/100
# 30000/30000 [==============================] - 317s 11ms/sample - loss: 0.0852 - segmentation_loss: 0.0031 - embedding_loss: 0.0821
# Epoch 18/100
# 30000/30000 [==============================] - 305s 10ms/sample - loss: 0.0807 - segmentation_loss: 0.0030 - embedding_loss: 0.0777
# Epoch 19/100
# 30000/30000 [==============================] - 306s 10ms/sample - loss: 0.0775 - segmentation_loss: 0.0029 - embedding_loss: 0.0746
# Epoch 20/100
# 30000/30000 [==============================] - 303s 10ms/sample - loss: 0.0737 - segmentation_loss: 0.0028 - embedding_loss: 0.0709
# Epoch 21/100
# 30000/30000 [==============================] - 304s 10ms/sample - loss: 0.0708 - segmentation_loss: 0.0027 - embedding_loss: 0.0681
# Epoch 22/100
# 30000/30000 [==============================] - 300s 10ms/sample - loss: 0.0681 - segmentation_loss: 0.0026 - embedding_loss: 0.0655
# Epoch 23/100
# 30000/30000 [==============================] - 301s 10ms/sample - loss: 0.0653 - segmentation_loss: 0.0026 - embedding_loss: 0.0627
# Epoch 24/100
# 30000/30000 [==============================] - 302s 10ms/sample - loss: 0.0636 - segmentation_loss: 0.0025 - embedding_loss: 0.0611
# Epoch 25/100
# 30000/30000 [==============================] - 299s 10ms/sample - loss: 0.0613 - segmentation_loss: 0.0025 - embedding_loss: 0.0588
# Epoch 26/100
# 30000/30000 [==============================] - 299s 10ms/sample - loss: 0.0590 - segmentation_loss: 0.0024 - embedding_loss: 0.0566
# Epoch 27/100
# 30000/30000 [==============================] - 300s 10ms/sample - loss: 0.0574 - segmentation_loss: 0.0024 - embedding_loss: 0.0550
# Epoch 28/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0561 - segmentation_loss: 0.0024 - embedding_loss: 0.0537
# Epoch 29/100
# 30000/30000 [==============================] - 300s 10ms/sample - loss: 0.0546 - segmentation_loss: 0.0023 - embedding_loss: 0.0523
# Epoch 30/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0532 - segmentation_loss: 0.0023 - embedding_loss: 0.0510
# Epoch 31/100
# 30000/30000 [==============================] - 300s 10ms/sample - loss: 0.0519 - segmentation_loss: 0.0023 - embedding_loss: 0.0497
# Epoch 32/100
# 30000/30000 [==============================] - 301s 10ms/sample - loss: 0.0503 - segmentation_loss: 0.0022 - embedding_loss: 0.0481
# Epoch 33/100
# 30000/30000 [==============================] - 302s 10ms/sample - loss: 0.0497 - segmentation_loss: 0.0022 - embedding_loss: 0.0475
# Epoch 34/100
# 30000/30000 [==============================] - 301s 10ms/sample - loss: 0.0488 - segmentation_loss: 0.0022 - embedding_loss: 0.0466
# Epoch 35/100
# 30000/30000 [==============================] - 302s 10ms/sample - loss: 0.0479 - segmentation_loss: 0.0022 - embedding_loss: 0.0458
# Epoch 36/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0466 - segmentation_loss: 0.0021 - embedding_loss: 0.0444
# Epoch 37/100
# 30000/30000 [==============================] - 299s 10ms/sample - loss: 0.0460 - segmentation_loss: 0.0021 - embedding_loss: 0.0439
# Epoch 38/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0449 - segmentation_loss: 0.0021 - embedding_loss: 0.0428
# Epoch 39/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0465 - segmentation_loss: 0.0022 - embedding_loss: 0.0443
# Epoch 40/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0435 - segmentation_loss: 0.0021 - embedding_loss: 0.0414
# Epoch 41/100
# 30000/30000 [==============================] - 299s 10ms/sample - loss: 0.0427 - segmentation_loss: 0.0020 - embedding_loss: 0.0407
# Epoch 42/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0421 - segmentation_loss: 0.0020 - embedding_loss: 0.0401
# Epoch 43/100
# 30000/30000 [==============================] - 299s 10ms/sample - loss: 0.0420 - segmentation_loss: 0.0020 - embedding_loss: 0.0400
# Epoch 44/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0413 - segmentation_loss: 0.0020 - embedding_loss: 0.0393
# Epoch 45/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0406 - segmentation_loss: 0.0020 - embedding_loss: 0.0386
# Epoch 46/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0399 - segmentation_loss: 0.0020 - embedding_loss: 0.0379
# Epoch 47/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0395 - segmentation_loss: 0.0020 - embedding_loss: 0.0375
# Epoch 48/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0392 - segmentation_loss: 0.0020 - embedding_loss: 0.0373
# Epoch 49/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0386 - segmentation_loss: 0.0019 - embedding_loss: 0.0367
# Epoch 50/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0382 - segmentation_loss: 0.0019 - embedding_loss: 0.0362
# Epoch 51/100
# 30000/30000 [==============================] - 300s 10ms/sample - loss: 0.0377 - segmentation_loss: 0.0019 - embedding_loss: 0.0357
# Epoch 52/100
# 30000/30000 [==============================] - 299s 10ms/sample - loss: 0.0373 - segmentation_loss: 0.0019 - embedding_loss: 0.0354
# Epoch 53/100
# 30000/30000 [==============================] - 301s 10ms/sample - loss: 0.0368 - segmentation_loss: 0.0019 - embedding_loss: 0.0349
# Epoch 54/100
# 30000/30000 [==============================] - 299s 10ms/sample - loss: 0.0366 - segmentation_loss: 0.0019 - embedding_loss: 0.0347
# Epoch 55/100
# 30000/30000 [==============================] - 299s 10ms/sample - loss: 0.0366 - segmentation_loss: 0.0019 - embedding_loss: 0.0347
# Epoch 56/100
# 30000/30000 [==============================] - 299s 10ms/sample - loss: 0.0353 - segmentation_loss: 0.0019 - embedding_loss: 0.0335
# Epoch 57/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0356 - segmentation_loss: 0.0019 - embedding_loss: 0.0337
# Epoch 58/100
# 30000/30000 [==============================] - 295s 10ms/sample - loss: 0.0349 - segmentation_loss: 0.0018 - embedding_loss: 0.0331
# Epoch 59/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0345 - segmentation_loss: 0.0018 - embedding_loss: 0.0327
# Epoch 60/100
# 30000/30000 [==============================] - 294s 10ms/sample - loss: 0.0345 - segmentation_loss: 0.0018 - embedding_loss: 0.0326
# Epoch 61/100
# 30000/30000 [==============================] - 295s 10ms/sample - loss: 0.0342 - segmentation_loss: 0.0018 - embedding_loss: 0.0324
# Epoch 62/100
# 30000/30000 [==============================] - 295s 10ms/sample - loss: 0.0338 - segmentation_loss: 0.0018 - embedding_loss: 0.0320
# Epoch 63/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0335 - segmentation_loss: 0.0018 - embedding_loss: 0.0317
# Epoch 64/100
# 30000/30000 [==============================] - 295s 10ms/sample - loss: 0.0335 - segmentation_loss: 0.0018 - embedding_loss: 0.0317
# Epoch 65/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0329 - segmentation_loss: 0.0018 - embedding_loss: 0.0311
# Epoch 66/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0329 - segmentation_loss: 0.0018 - embedding_loss: 0.0311
# Epoch 67/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0326 - segmentation_loss: 0.0018 - embedding_loss: 0.0309
# Epoch 68/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0324 - segmentation_loss: 0.0018 - embedding_loss: 0.0306
# Epoch 69/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0319 - segmentation_loss: 0.0018 - embedding_loss: 0.0301
# Epoch 70/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0318 - segmentation_loss: 0.0018 - embedding_loss: 0.0300
# Epoch 71/100
# 30000/30000 [==============================] - 295s 10ms/sample - loss: 0.0318 - segmentation_loss: 0.0018 - embedding_loss: 0.0301
# Epoch 72/100
# 30000/30000 [==============================] - 295s 10ms/sample - loss: 0.0313 - segmentation_loss: 0.0017 - embedding_loss: 0.0296
# Epoch 73/100
# 30000/30000 [==============================] - 295s 10ms/sample - loss: 0.0314 - segmentation_loss: 0.0018 - embedding_loss: 0.0297
# Epoch 74/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0306 - segmentation_loss: 0.0017 - embedding_loss: 0.0288
# Epoch 75/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0310 - segmentation_loss: 0.0017 - embedding_loss: 0.0293
# Epoch 76/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0308 - segmentation_loss: 0.0017 - embedding_loss: 0.0291
# Epoch 77/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0302 - segmentation_loss: 0.0017 - embedding_loss: 0.0285
# Epoch 78/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0302 - segmentation_loss: 0.0017 - embedding_loss: 0.0285
# Epoch 79/100
# 30000/30000 [==============================] - 295s 10ms/sample - loss: 0.0301 - segmentation_loss: 0.0017 - embedding_loss: 0.0283
# Epoch 80/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0299 - segmentation_loss: 0.0017 - embedding_loss: 0.0282
# Epoch 81/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0295 - segmentation_loss: 0.0017 - embedding_loss: 0.0278
# Epoch 82/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0297 - segmentation_loss: 0.0017 - embedding_loss: 0.0280
# Epoch 83/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0294 - segmentation_loss: 0.0017 - embedding_loss: 0.0277
# Epoch 84/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0292 - segmentation_loss: 0.0017 - embedding_loss: 0.0275
# Epoch 85/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0291 - segmentation_loss: 0.0017 - embedding_loss: 0.0274
# Epoch 86/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0288 - segmentation_loss: 0.0017 - embedding_loss: 0.0271
# Epoch 87/100
# 30000/30000 [==============================] - 299s 10ms/sample - loss: 0.0287 - segmentation_loss: 0.0017 - embedding_loss: 0.0271
# Epoch 88/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0287 - segmentation_loss: 0.0017 - embedding_loss: 0.0271
# Epoch 89/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0284 - segmentation_loss: 0.0017 - embedding_loss: 0.0267
# Epoch 90/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0283 - segmentation_loss: 0.0017 - embedding_loss: 0.0267
# Epoch 91/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0287 - segmentation_loss: 0.0017 - embedding_loss: 0.0271
# Epoch 92/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0279 - segmentation_loss: 0.0016 - embedding_loss: 0.0263
# Epoch 93/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0278 - segmentation_loss: 0.0016 - embedding_loss: 0.0262
# Epoch 94/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0279 - segmentation_loss: 0.0017 - embedding_loss: 0.0263
# Epoch 95/100
# 30000/30000 [==============================] - 294s 10ms/sample - loss: 0.0277 - segmentation_loss: 0.0016 - embedding_loss: 0.0261
# Epoch 96/100
# 30000/30000 [==============================] - 297s 10ms/sample - loss: 0.0274 - segmentation_loss: 0.0016 - embedding_loss: 0.0258
# Epoch 97/100
# 30000/30000 [==============================] - 294s 10ms/sample - loss: 0.0277 - segmentation_loss: 0.0016 - embedding_loss: 0.0261
# Epoch 98/100
# 30000/30000 [==============================] - 298s 10ms/sample - loss: 0.0271 - segmentation_loss: 0.0016 - embedding_loss: 0.0255
# Epoch 99/100
# 30000/30000 [==============================] - 295s 10ms/sample - loss: 0.0273 - segmentation_loss: 0.0016 - embedding_loss: 0.0257
# Epoch 100/100
# 30000/30000 [==============================] - 296s 10ms/sample - loss: 0.0270 - segmentation_loss: 0.0016 - embedding_loss: 0.0253

# %%
X_test = X_train
Y_test = Y_train

# %%
idx = np.random.randint(X_test.shape[0])
for channel in range(2):

    plt.figure(figsize=(12,8))
    ax = plt.subplot(151)
    ax.imshow(X_test[idx])
    ax.axis("off")
    ax.set_title("Input")
    ax = plt.subplot(152)
    segmentation = Y_test[idx,:,:,channel] > 0
    ax.imshow(Y_test[idx,:,:,channel], cmap="gray")
    ax.axis("off")
    ax.set_title("GT")

    segmentation_pred, embedding_pred = model.predict(X_test[idx:idx+1])
    segmentation_pred, embedding_pred = segmentation_pred[0][..., channel], embedding_pred[0]
    #embedding_pred_scaled = embedding_pred - np.min(embedding_pred)
    embedding_pred_scaled = embedding_pred# / np.max(embedding_pred_scaled)

    ax = plt.subplot(153)
    ax.imshow(segmentation_pred)
    ax.set_title("Segmentation pred")
    ax.axis("off")

    ax = plt.subplot(154)
    ax.imshow(embedding_pred_scaled)
    ax.set_title("Embeddings")
    ax.axis("off")

    discretized_emb = embeddings_to_instances(embedding_pred, segmentation_pred > 0.5,
                                              embedding_distance_threshold=1.25)

    ax = plt.subplot(155)
    ax.imshow(discretized_emb)
    ax.set_title(f"Instances pred = {len(np.unique(discretized_emb))-1}")
    ax.axis("off")
    plt.show()

    plt.figure(figsize=(15,12))
    for i, label in enumerate(np.unique(discretized_emb)):
        if label != -1:
            ax = plt.subplot(191+i)
            ax.imshow(discretized_emb == label)
            ax.axis("off")
    plt.show()
